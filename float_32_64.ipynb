# %%
import torch
import numpy as np

a = torch.finfo(torch.float64).min

a_t = torch.tensor(a, dtype = torch.float32)

print(a_t)

a_64 = torch.tensor(a, dtype = torch.float64)

print(a_64)
# Out:
# tensor(-inf)
# tensor(-1.7977e+308, dtype=torch.float64)

# %%
torch.finfo(torch.float64).min
# Out:
# -1.7976931348623157e+308
